# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import mmcv
import utils
import integration

# %%
name = "cm_rcnn_10164_a34"
cfg = './cfg/anchors/cm_rcnn_10164_a34.py'

coco_types = ["bbox", "segm"]
voc_types = ["bbox", "segm"]
thresh = [0.5, 0.75]

# %%
integration.integrated_coco_eval(name, cfg, coco_types)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 8.9 task/s, elapsed: 31s, ETA:     0scm_rcnn_10164_a34 detection datasets done!
#
# Writing detected results to ../detection/cm_rcnn_10164_a34/eval_result.pkl
# ......
# Writing done to pkl file: ../detection/cm_rcnn_10164_a34/eval_result.pkl
#
# Writing formatted results to ../detection/cm_rcnn_10164_a34/eval_result.json
# ......
# Writing done to json file: ../detection/cm_rcnn_10164_a34/eval_result.json
#
# Starting evaluate bbox and segm ......
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.10s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.781
# ...

# %%
integration.integrated_voc_eval(name, cfg, voc_types, thresh)
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# Preparing dataset ......
# [Dataset is ready now !]
# Ready to formatting on *bbox* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 76.9 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a34/bbox_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 313/313, 2262.2 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [313])file saved done in ../detection/cm_rcnn_10164_a34/bbox_dets.pkl
# Ready to evaluate on *bbox* ...
#
# TP: (2, 313)
# FP: (2, 313)
# FPR: (2, 313)
# TPR: (2, 313)
# AREA: [0.95465253 0.89963716] (2,)
# AP [0.97404804 0.87676066] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a34/voc_bbox_0.5_0.75.pkl]
# ...

# %%
integration.integrated_loss_curve(name, save=True)
# Out:
#  Save done![../detection/cm_rcnn_10164_a34/learning_curve.png]
#  Save done![../detection/cm_rcnn_10164_a34/learing_rate.png]
