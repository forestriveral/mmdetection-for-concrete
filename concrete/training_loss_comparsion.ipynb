# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
import evaluation
import detection
import datasets
import visualization
from comparsion import read_logs

# %%
log_path = [
            #"../work_dirs/cm_rcnn_10164_step0/20190426_180742.log",
            "../work_dirs/cm_rcnn_10164_step/20190425_143827.log",
            "../work_dirs/cm_rcnn_10164_exp/20190426_094123.log",
            "../work_dirs/cm_rcnn_10164_poly/20190426_121135.log",
            "../work_dirs/cm_rcnn_10164_inv/20190426_135837.log",
            "../work_dirs/cm_rcnn_10164_cos/20190426_163138.log",
            
           ]

# %%
read_logs(log_path, obj="loss", save=None)

# %%
read_logs(log_path, obj="val", save=None)

# %%
log_path_1 = [
            "../work_dirs/cm_rcnn_10164_step0/20190426_180742.log",
            "../work_dirs/cm_rcnn_10164_step/20190425_143827.log",
            "../work_dirs/cm_rcnn_10164_m56/20190427_150555.log",
             ]

# %%
read_logs(log_path_1, obj="loss", save=None)

# %%
read_logs(log_path_1, obj="val", save=None)
