# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import mmcv
import utils
import integration

# %%
name = "cm_rcnn_10164_a3"
cfg = './cfg/anchors/cm_rcnn_10164_a3.py'

coco_types = ["bbox", "segm"]
voc_types = ["bbox", "segm"]
thresh = [0.5, 0.75]

# %%
integration.integrated_coco_eval(name, cfg, coco_types)
# Out:
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 9.1 task/s, elapsed: 31s, ETA:     0scm_rcnn_10164_a3 detection datasets done!
#
# Writing detected results to ../detection/cm_rcnn_10164_a3/eval_result.pkl
# ......
# Writing done to pkl file: ../detection/cm_rcnn_10164_a3/eval_result.pkl
#
# Writing formatted results to ../detection/cm_rcnn_10164_a3/eval_result.json
# ......
# Writing done to json file: ../detection/cm_rcnn_10164_a3/eval_result.json
#
# Starting evaluate bbox and segm ......
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.782
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.978
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.880
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.819
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.818
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.782
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.814
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.823
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.823
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.823
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.823
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.823
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.12s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.891
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.323
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.524
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.523
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.517
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.525
# pdframe data written done![../detection/cm_rcnn_10164_a3/coco_val.csv]

# %%
integration.integrated_voc_eval(name, cfg, voc_types, thresh)
# Out:
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# Preparing dataset ......
# [Dataset is ready now !]
# Ready to formatting on *bbox* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 71.7 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a3/bbox_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 316/316, 2185.5 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [316])file saved done in ../detection/cm_rcnn_10164_a3/bbox_dets.pkl
# Ready to evaluate on *bbox* ...
#
# TP: (2, 316)
# FP: (2, 316)
# FPR: (2, 316)
# TPR: (2, 316)
# AREA: [0.98338468 0.90975275] (2,)
# AP [0.98082193 0.8780478 ] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a3/voc_bbox_0.5_0.75.pkl]
# (2, 318) <class 'numpy.ndarray'>
# (2, 318) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 318) <class 'numpy.ndarray'>
# (2, 318) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a3/bbox_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a3/bbox_roc.png]
# Ready to formatting on *segm* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 73.7 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a3/segm_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 316/316, 917.7 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [316])file saved done in ../detection/cm_rcnn_10164_a3/segm_dets.pkl
# Ready to evaluate on *segm* ...
#
# TP: (2, 316)
# FP: (2, 316)
# FPR: (2, 316)
# TPR: (2, 316)
# AREA: [0.83208099 0.63557692] (2,)
# AP [0.89136092 0.32492596] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a3/voc_segm_0.5_0.75.pkl]
# (2, 318) <class 'numpy.ndarray'>
# (2, 318) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 318) <class 'numpy.ndarray'>
# (2, 318) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a3/segm_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a3/segm_roc.png]

# %%
integration.integrated_loss_curve(name, save=True)
# Out:
#  Save done![../detection/cm_rcnn_10164_a3/learning_curve.png]
#  Save done![../detection/cm_rcnn_10164_a3/learing_rate.png]
