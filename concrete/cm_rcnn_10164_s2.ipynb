# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import mmcv
import utils
import integration

# %%
name = "cm_rcnn_10164_s2"
cfg = './cfg/scales/cm_rcnn_10164_s2.py'

coco_types = ["bbox", "segm"]
voc_types = ["bbox", "segm"]
thresh = [0.5, 0.75]

# %%
integration.integrated_coco_eval(name, cfg, coco_types)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 9.1 task/s, elapsed: 31s, ETA:     0scm_rcnn_10164_s2 detection datasets done!
#
# Writing detected results to ../detection/cm_rcnn_10164_s2/eval_result.pkl
# ......
# Writing done to pkl file: ../detection/cm_rcnn_10164_s2/eval_result.pkl
#
# Writing formatted results to ../detection/cm_rcnn_10164_s2/eval_result.json
# ......
# Writing done to json file: ../detection/cm_rcnn_10164_s2/eval_result.json
#
# Starting evaluate bbox and segm ......
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.10s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.773
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.964
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.878
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.821
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.820
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.773
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.809
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.822
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.13s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.409
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.891
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.510
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.509
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.409
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.501
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.510
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.510
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.510
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.510
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.510
# pdframe data written done![../detection/cm_rcnn_10164_s2/coco_val.csv]

# %%
integration.integrated_voc_eval(name, cfg, voc_types, thresh)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Preparing dataset ......
# [Dataset is ready now !]
# Ready to formatting on *bbox* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 78.3 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_s2/bbox_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 315/315, 2211.9 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [315])file saved done in ../detection/cm_rcnn_10164_s2/bbox_dets.pkl
# Ready to evaluate on *bbox* ...
#
# TP: (2, 315)
# FP: (2, 315)
# FPR: (2, 315)
# TPR: (2, 315)
# AREA: [0.9473458  0.86664336] (2,)
# AP [0.96941272 0.86726399] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_s2/voc_bbox_0.5_0.75.pkl]
# (2, 317) <class 'numpy.ndarray'>
# (2, 317) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 317) <class 'numpy.ndarray'>
# (2, 317) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_s2/bbox_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_s2/bbox_roc.png]
# Ready to formatting on *segm* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 79.9 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_s2/segm_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 315/315, 1313.3 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [315])file saved done in ../detection/cm_rcnn_10164_s2/segm_dets.pkl
# Ready to evaluate on *segm* ...
#
# TP: (2, 315)
# FP: (2, 315)
# FPR: (2, 315)
# TPR: (2, 315)
# AREA: [0.82172297 0.63489238] (2,)
# AP [0.89154995 0.30502067] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_s2/voc_segm_0.5_0.75.pkl]
# (2, 317) <class 'numpy.ndarray'>
# (2, 317) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 317) <class 'numpy.ndarray'>
# (2, 317) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_s2/segm_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_s2/segm_roc.png]

# %%
integration.integrated_loss_curve(name, save=True)
# Out:
#  Save done![../detection/cm_rcnn_10164_s2/learning_curve.png]
#  Save done![../detection/cm_rcnn_10164_s2/learing_rate.png]
