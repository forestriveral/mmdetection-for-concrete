# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import mmcv
import utils
import integration

# %%
name = "cm_rcnn_10164_s3"
cfg = './cfg/scales/cm_rcnn_10164_s3.py'

coco_types = ["bbox", "segm"]
voc_types = ["bbox", "segm"]
thresh = [0.5, 0.75]

# %%
integration.integrated_coco_eval(name, cfg, coco_types)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 9.1 task/s, elapsed: 31s, ETA:     0scm_rcnn_10164_s3 detection datasets done!
#
# Writing detected results to ../detection/cm_rcnn_10164_s3/eval_result.pkl
# ......
# Writing done to pkl file: ../detection/cm_rcnn_10164_s3/eval_result.pkl
#
# Writing formatted results to ../detection/cm_rcnn_10164_s3/eval_result.json
# ......
# Writing done to json file: ../detection/cm_rcnn_10164_s3/eval_result.json
#
# Starting evaluate bbox and segm ......
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.772
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.976
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.876
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.812
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.811
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.773
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.804
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.815
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.12s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.412
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.878
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.512
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.511
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.412
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.512
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.512
# pdframe data written done![../detection/cm_rcnn_10164_s3/coco_val.csv]

# %%
integration.integrated_voc_eval(name, cfg, voc_types, thresh)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Preparing dataset ......
# [Dataset is ready now !]
# Ready to formatting on *bbox* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 76.8 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_s3/bbox_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 313/313, 1870.0 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [313])file saved done in ../detection/cm_rcnn_10164_s3/bbox_dets.pkl
# Ready to evaluate on *bbox* ...
#
# TP: (2, 313)
# FP: (2, 313)
# FPR: (2, 313)
# TPR: (2, 313)
# AREA: [0.96466731 0.887442  ] (2,)
# AP [0.97888665 0.8817838 ] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_s3/voc_bbox_0.5_0.75.pkl]
# (2, 315) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_s3/bbox_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_s3/bbox_roc.png]
# Ready to formatting on *segm* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 73.4 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_s3/segm_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 313/313, 1040.4 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [313])file saved done in ../detection/cm_rcnn_10164_s3/segm_dets.pkl
# Ready to evaluate on *segm* ...
#
# TP: (2, 313)
# FP: (2, 313)
# FPR: (2, 313)
# TPR: (2, 313)
# AREA: [0.80331675 0.62537814] (2,)
# AP [0.88422451 0.31588399] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_s3/voc_segm_0.5_0.75.pkl]
# (2, 315) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_s3/segm_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_s3/segm_roc.png]

# %%
integration.integrated_loss_curve(name, save=True)
# Out:
#  Save done![../detection/cm_rcnn_10164_s3/learning_curve.png]
#  Save done![../detection/cm_rcnn_10164_s3/learing_rate.png]
