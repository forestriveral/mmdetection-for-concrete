# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import mmcv
import utils
import integration

# %%
name = "cm_rcnn_10164_a4"
cfg = './cfg/anchors/cm_rcnn_10164_a4.py'

coco_types = ["bbox", "segm"]
voc_types = ["bbox", "segm"]
thresh = [0.5, 0.75]

# %%
integration.integrated_coco_eval(name, cfg, coco_types)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 9.2 task/s, elapsed: 30s, ETA:     0scm_rcnn_10164_a4 detection datasets done!
#
# Writing detected results to ../detection/cm_rcnn_10164_a4/eval_result.pkl
# ......
# Writing done to pkl file: ../detection/cm_rcnn_10164_a4/eval_result.pkl
#
# Writing formatted results to ../detection/cm_rcnn_10164_a4/eval_result.json
# ......
# Writing done to json file: ../detection/cm_rcnn_10164_a4/eval_result.json
#
# Starting evaluate bbox and segm ......
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.779
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.879
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.821
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.821
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.779
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.815
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.825
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.12s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.416
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.895
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.344
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.522
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.522
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.416
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.524
# pdframe data written done![../detection/cm_rcnn_10164_a4/coco_val.csv]

# %%
integration.integrated_voc_eval(name, cfg, voc_types, thresh)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Preparing dataset ......
# [Dataset is ready now !]
# Ready to formatting on *bbox* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 80.6 task/s, elapsed: 3s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a4/bbox_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 313/313, 2102.7 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [313])file saved done in ../detection/cm_rcnn_10164_a4/bbox_dets.pkl
# Ready to evaluate on *bbox* ...
#
# TP: (2, 313)
# FP: (2, 313)
# FPR: (2, 313)
# TPR: (2, 313)
# AREA: [0.98604438 0.9142344 ] (2,)
# AP [0.97427409 0.88745402] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a4/voc_bbox_0.5_0.75.pkl]
# (2, 315) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a4/bbox_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a4/bbox_roc.png]
# Ready to formatting on *segm* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 76.0 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a4/segm_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 313/313, 1163.9 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [313])file saved done in ../detection/cm_rcnn_10164_a4/segm_dets.pkl
# Ready to evaluate on *segm* ...
#
# TP: (2, 313)
# FP: (2, 313)
# FPR: (2, 313)
# TPR: (2, 313)
# AREA: [0.85189253 0.62528604] (2,)
# AP [0.8948109  0.34346868] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a4/voc_segm_0.5_0.75.pkl]
# (2, 315) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2, 315) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a4/segm_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a4/segm_roc.png]

# %%
integration.integrated_loss_curve(name, save=True)
# Out:
#  Save done![../detection/cm_rcnn_10164_a4/learning_curve.png]
#  Save done![../detection/cm_rcnn_10164_a4/learing_rate.png]
