# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import mmcv
import utils
import integration

# %%
name = "cm_rcnn_10164_s1"
cfg = './cfg/scales/cm_rcnn_10164_s1.py'

coco_types = ["bbox", "segm"]
voc_types = ["bbox", "segm"]
thresh = [0.5, 0.75]

# %%
integration.integrated_coco_eval(name, cfg, coco_types)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 9.0 task/s, elapsed: 31s, ETA:     0scm_rcnn_10164_s1 detection datasets done!
#
# Writing detected results to ../detection/cm_rcnn_10164_s1/eval_result.pkl
# ......
# Writing done to pkl file: ../detection/cm_rcnn_10164_s1/eval_result.pkl
#
# Writing formatted results to ../detection/cm_rcnn_10164_s1/eval_result.json
# ......
# Writing done to json file: ../detection/cm_rcnn_10164_s1/eval_result.json
#
# Starting evaluate bbox and segm ......
# Loading and preparing results...
# DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.783
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.968
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.900
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.824
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.823
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.817
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.828
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.828
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.828
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.828
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.828
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.12s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.419
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.890
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.313
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.524
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.523
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.525
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.525
# pdframe data written done![../detection/cm_rcnn_10164_s1/coco_val.csv]

# %%
integration.integrated_voc_eval(name, cfg, voc_types, thresh)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Preparing dataset ......
# [Dataset is ready now !]
# Ready to formatting on *bbox* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 76.4 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_s1/bbox_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 308/308, 2098.0 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [308])file saved done in ../detection/cm_rcnn_10164_s1/bbox_dets.pkl
# Ready to evaluate on *bbox* ...
#
# TP: (2, 308)
# FP: (2, 308)
# FPR: (2, 308)
# TPR: (2, 308)
# AREA: [0.97817785 0.88468627] (2,)
# AP [0.97380702 0.89461557] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_s1/voc_bbox_0.5_0.75.pkl]
# (2, 310) <class 'numpy.ndarray'>
# (2, 310) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 310) <class 'numpy.ndarray'>
# (2, 310) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_s1/bbox_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_s1/bbox_roc.png]
# Ready to formatting on *segm* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 79.9 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_s1/segm_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 308/308, 1325.3 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [308])file saved done in ../detection/cm_rcnn_10164_s1/segm_dets.pkl
# Ready to evaluate on *segm* ...
#
# TP: (2, 308)
# FP: (2, 308)
# FPR: (2, 308)
# TPR: (2, 308)
# AREA: [0.77241448 0.60881299] (2,)
# AP [0.89671387 0.31209755] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_s1/voc_segm_0.5_0.75.pkl]
# (2, 310) <class 'numpy.ndarray'>
# (2, 310) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 310) <class 'numpy.ndarray'>
# (2, 310) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_s1/segm_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_s1/segm_roc.png]

# %%
integration.integrated_loss_curve(name, save=True)
# Out:
#  Save done![../detection/cm_rcnn_10164_s1/learning_curve.png]
#  Save done![../detection/cm_rcnn_10164_s1/learing_rate.png]
