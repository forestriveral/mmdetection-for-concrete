# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import mmcv
import utils
import integration

# %%
name = "cm_rcnn_10164_a3510"
cfg = './cfg/anchors/cm_rcnn_10164_a3510.py'

coco_types = ["bbox", "segm"]
voc_types = ["bbox", "segm"]
thresh = [0.5, 0.75]

# %%
integration.integrated_coco_eval(name, cfg, coco_types)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 9.1 task/s, elapsed: 31s, ETA:     0scm_rcnn_10164_a3510 detection datasets done!
#
# Writing detected results to ../detection/cm_rcnn_10164_a3510/eval_result.pkl
# ......
# Writing done to pkl file: ../detection/cm_rcnn_10164_a3510/eval_result.pkl
#
# Writing formatted results to ../detection/cm_rcnn_10164_a3510/eval_result.json
# ......
# Writing done to json file: ../detection/cm_rcnn_10164_a3510/eval_result.json
#
# Starting evaluate bbox and segm ......
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.784
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.969
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.886
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.820
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.819
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.784
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.811
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.822
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.822
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.12s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.426
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.904
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.335
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.526
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.426
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.526
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.526
# pdframe data written done![../detection/cm_rcnn_10164_a3510/coco_val.csv]

# %%
integration.integrated_voc_eval(name, cfg, voc_types, thresh)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Preparing dataset ......
# [Dataset is ready now !]
# Ready to formatting on *bbox* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 81.9 task/s, elapsed: 3s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a3510/bbox_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 310/310, 2461.5 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [310])file saved done in ../detection/cm_rcnn_10164_a3510/bbox_dets.pkl
# Ready to evaluate on *bbox* ...
#
# TP: (2, 310)
# FP: (2, 310)
# FPR: (2, 310)
# TPR: (2, 310)
# AREA: [0.98746201 0.92239186] (2,)
# AP [0.97454713 0.8913907 ] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a3510/voc_bbox_0.5_0.75.pkl]
# (2, 312) <class 'numpy.ndarray'>
# (2, 312) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 312) <class 'numpy.ndarray'>
# (2, 312) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a3510/bbox_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a3510/bbox_roc.png]
# Ready to formatting on *segm* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 80.8 task/s, elapsed: 3s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a3510/segm_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 310/310, 1125.4 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [310])file saved done in ../detection/cm_rcnn_10164_a3510/segm_dets.pkl
# Ready to evaluate on *segm* ...
#
# TP: (2, 310)
# FP: (2, 310)
# FPR: (2, 310)
# TPR: (2, 310)
# AREA: [0.86037037 0.62595229] (2,)
# AP [0.90769466 0.3324434 ] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a3510/voc_segm_0.5_0.75.pkl]
# (2, 312) <class 'numpy.ndarray'>
# (2, 312) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 312) <class 'numpy.ndarray'>
# (2, 312) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a3510/segm_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a3510/segm_roc.png]

# %%
integration.integrated_loss_curve(name, save=True)
# Out:
#  Save done![../detection/cm_rcnn_10164_a3510/learning_curve.png]
#  Save done![../detection/cm_rcnn_10164_a3510/learing_rate.png]
