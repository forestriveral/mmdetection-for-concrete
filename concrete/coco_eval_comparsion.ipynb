# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np
from comparsion import read_coco_eval

# %%
coco_path = [
            "../detection/cm_rcnn_10164_step",
            "../detection/cm_rcnn_10164_step0",
            "../detection/cm_rcnn_10164_exp",
            "../detection/cm_rcnn_10164_poly",
            "../detection/cm_rcnn_10164_inv",
            "../detection/cm_rcnn_10164_cos",
            "../detection/cm_rcnn_10164_m56",
            "../detection/cm_rcnn_10132",
            "../detection/cm_rcnn_101",
            "../detection/cm_rcnn_50",
            "../detection/cm_rcnn_dconv",
            "../detection/mask_rcnn_r50",
            "../detection/cascade_rcnn_r50",
            "../detection/faster_rcnn_r50",
            "../detection/retinanet_r50",
            ]

# %%
result = read_coco_eval(coco_path, save=None)

# %%
result
# Out:
#                   name  params  bbox_mAP  bbox_50  bbox_75 segm_mAP segm_50  \
# 0        cm_rcnn_10164     NaN     0.783    0.978    0.878    0.417   0.894
# 0  cm_rcnn_10164_step0     NaN     0.764    0.968    0.845    0.412   0.873
# 0    cm_rcnn_10164_exp     NaN     0.766    0.968    0.885    0.412   0.883
# 0   cm_rcnn_10164_poly     NaN     0.750    0.966    0.855    0.405   0.877
# 0    cm_rcnn_10164_inv     NaN     0.695    0.962    0.834     0.38   0.883
# 0    cm_rcnn_10164_cos     NaN     0.758    0.967    0.868    0.408   0.885
# 0    cm_rcnn_10164_m56     NaN     0.783    0.969    0.903    0.422   0.885
# 0        cm_rcnn_10132     NaN     0.775    0.970    0.892    0.421   0.898
# 0          cm_rcnn_101     NaN     0.758    0.978    0.881    0.415   0.883
# 0           cm_rcnn_50     NaN     0.728    0.969    0.867    0.411   0.885
# 0        cm_rcnn_dconv     NaN     0.761    0.969    0.870    0.412   0.896
# 0        mask_rcnn_r50     NaN     0.722    0.970    0.847    0.396    0.87
# 0     cascade_rcnn_r50     NaN     0.770    0.959    0.857     None    None
# 0      faster_rcnn_r50     NaN     0.715    0.966    0.828     None    None
# 0        retinanet_r50     NaN     0.718    0.953    0.817     None    None
#
#   segm_75
# 0   0.299
# 0   0.304
# 0   0.319
# 0   0.301
# 0   0.245
# 0   0.323
# 0   0.335
# 0   0.336
# 0   0.323
# 0     0.3
# 0   0.317
# 0   0.293
# 0    None
# 0    None
# 0    None

# %%
name = [
        "cm_rcnn_10164_a3",
        "cm_rcnn_10164_a4",
        "cm_rcnn_10164_a5",
        "cm_rcnn_10164_a10",
        "cm_rcnn_10164_a34",
        "cm_rcnn_10164_a3510",
        "cm_rcnn_10164_s1",
        "cm_rcnn_10164_s2",
        "cm_rcnn_10164_s3",
        ]

# %%
read_coco_eval(name, save=None)
# Out:
#                   name  params  bbox_mAP  bbox_50  bbox_75  segm_mAP  segm_50  \
# 0     cm_rcnn_10164_a3     NaN     0.782    0.978    0.880     0.419    0.891
# 0     cm_rcnn_10164_a4     NaN     0.779    0.969    0.879     0.416    0.895
# 0     cm_rcnn_10164_a5     NaN     0.783    0.979    0.879     0.420    0.892
# 0    cm_rcnn_10164_a10     NaN     0.791    0.979    0.903     0.432    0.885
# 0    cm_rcnn_10164_a34     NaN     0.781    0.975    0.879     0.417    0.901
# 0  cm_rcnn_10164_a3510     NaN     0.784    0.969    0.886     0.426    0.904
# 0     cm_rcnn_10164_s1     NaN     0.783    0.968    0.900     0.419    0.890
# 0     cm_rcnn_10164_s2     NaN     0.773    0.964    0.878     0.409    0.891
# 0     cm_rcnn_10164_s3     NaN     0.772    0.976    0.876     0.412    0.878
#
#    segm_75
# 0    0.323
# 0    0.344
# 0    0.324
# 0    0.356
# 0    0.351
# 0    0.335
# 0    0.313
# 0    0.309
# 0    0.319
