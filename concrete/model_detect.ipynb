# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import detection
import mmcv
import numpy as np
import matplotlib.pyplot as plt
from mmdet.apis import inference_detector

# %%
score_thr= 0.0
cfg = './cm_rcnn_10164.py'
dataset = "concrete"
#dataset = "coco"
output = '../detection/cm_rcnn_10164_1/eval_result.json'
model_path = '../work_dirs/cm_rcnn_10164_1/latest.pth'
image_1 = "../data/coco/test/256_02015.png"
image_2 = "../data/coco/test/256_02153.png"
image_3 = "../data/coco/test/256_02076.png"

# %%
c, m = detection.initiate_detector(cfg, model_path)

# %%
# single_detect(c, m, image_path, save="./images/detected/person.jpg")
detection.single_detect_plot(c, m, image_1, dataset, score_thr, save=None)
# Out:
# [162 141 173 153   0]

# %%
detection.single_detect_plot(c, m, image_2, dataset, score_thr, save=None)
# Out:
# Image size: (256, 256)

# %%
detection.single_detect_plot(c, m, image_3, dataset, score_thr, save=None)
# Out:
# Image size: (256, 256)
