# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import core.detection as detection
import mmcv
import numpy as np
import matplotlib.pyplot as plt
from mmdet.apis import inference_detector

# %%
score_thr= 0.5
cfg = './cfg/anchors/cm_rcnn_10164_a3510.py'
dataset = "crack"
#dataset = "coco"
#output = '../detection/cm_rcnn_10164_1/eval_result.json'
model_path = '../work_dirs/cm_rcnn_10164_a3510/latest.pth'

# %%
c, m = detection.initiate_detector(cfg, model_path)

# %%
image_1 = "../data/coco/test_origin/1024_00001.jpg"
# single_detect(c, m, image_path, save="./images/detected/person.jpg")
detection.single_detect_plot(c, m, image_1, dataset, score_thr, save=None)

# %%
image_2 = "../data/coco/test_origin/1024_00002.jpg"
detection.single_detect_plot(c, m, image_2, dataset, score_thr, save=None)

# %%
image_3 = "../data/coco/test_origin/1024_00006.jpg"
detection.single_detect_plot(c, m, image_3, dataset, score_thr, save=None)
