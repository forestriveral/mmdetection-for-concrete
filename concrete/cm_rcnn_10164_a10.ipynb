# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import mmcv
import utils
import integration

# %%
name = "cm_rcnn_10164_a10"
cfg = './cfg/anchors/cm_rcnn_10164_a10.py'

coco_types = ["bbox", "segm"]
voc_types = ["bbox", "segm"]
thresh = [0.5, 0.75]

# %%
integration.integrated_coco_eval(name, cfg, coco_types)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 9.1 task/s, elapsed: 31s, ETA:     0scm_rcnn_10164_a10 detection datasets done!
#
# Writing detected results to ../detection/cm_rcnn_10164_a10/eval_result.pkl
# ......
# Writing done to pkl file: ../detection/cm_rcnn_10164_a10/eval_result.pkl
#
# Writing formatted results to ../detection/cm_rcnn_10164_a10/eval_result.json
# ......
# Writing done to json file: ../detection/cm_rcnn_10164_a10/eval_result.json
#
# Starting evaluate bbox and segm ......
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.09s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.791
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.903
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.829
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.828
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.792
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.819
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.832
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.832
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.11s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.432
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.885
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.356
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.530
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.529
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.432
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.519
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.530
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.530
# pdframe data written done![../detection/cm_rcnn_10164_a10/coco_val.csv]

# %%
integration.integrated_voc_eval(name, cfg, voc_types, thresh)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Preparing dataset ......
# [Dataset is ready now !]
# Ready to formatting on *bbox* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 78.8 task/s, elapsed: 4s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a10/bbox_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 305/305, 2846.7 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [305])file saved done in ../detection/cm_rcnn_10164_a10/bbox_dets.pkl
# Ready to evaluate on *bbox* ...
#
# TP: (2, 305)
# FP: (2, 305)
# FPR: (2, 305)
# TPR: (2, 305)
# AREA: [0.98239437 0.89713594] (2,)
# AP [0.98141323 0.91010829] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a10/voc_bbox_0.5_0.75.pkl]
# (2, 307) <class 'numpy.ndarray'>
# (2, 307) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 307) <class 'numpy.ndarray'>
# (2, 307) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a10/bbox_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a10/bbox_roc.png]
# Ready to formatting on *segm* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 82.3 task/s, elapsed: 3s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a10/segm_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 305/305, 1254.7 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [305])file saved done in ../detection/cm_rcnn_10164_a10/segm_dets.pkl
# Ready to evaluate on *segm* ...
#
# TP: (2, 305)
# FP: (2, 305)
# FPR: (2, 305)
# TPR: (2, 305)
# AREA: [0.80687777 0.63159938] (2,)
# AP [0.89076408 0.35587468] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a10/voc_segm_0.5_0.75.pkl]
# (2, 307) <class 'numpy.ndarray'>
# (2, 307) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 307) <class 'numpy.ndarray'>
# (2, 307) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a10/segm_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a10/segm_roc.png]

# %%
integration.integrated_loss_curve(name, save=True)
# Out:
#  Save done![../detection/cm_rcnn_10164_a10/learning_curve.png]
#  Save done![../detection/cm_rcnn_10164_a10/learing_rate.png]
