# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import os
import mmcv
import utils
import integration

# %%
name = "cm_rcnn_10164_a5"
cfg = './cfg/anchors/cm_rcnn_10164_a5.py'

coco_types = ["bbox", "segm"]
voc_types = ["bbox", "segm"]
thresh = [0.5, 0.75]

# %%
integration.integrated_coco_eval(name, cfg, coco_types)
# Out:
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 9.0 task/s, elapsed: 31s, ETA:     0scm_rcnn_10164_a5 detection datasets done!
#
# Writing detected results to ../detection/cm_rcnn_10164_a5/eval_result.pkl
# ......
# Writing done to pkl file: ../detection/cm_rcnn_10164_a5/eval_result.pkl
#
# Writing formatted results to ../detection/cm_rcnn_10164_a5/eval_result.json
# ......
# Writing done to json file: ../detection/cm_rcnn_10164_a5/eval_result.json
#
# Starting evaluate bbox and segm ......
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.11s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.783
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.979
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.879
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.822
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.822
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.783
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.810
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.825
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.825
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.14s).
# Accumulating evaluation results...
# DONE (t=0.03s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.420
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.892
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.324
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.526
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.525
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.420
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.514
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.527
# pdframe data written done![../detection/cm_rcnn_10164_a5/coco_val.csv]

# %%
integration.integrated_voc_eval(name, cfg, voc_types, thresh)
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Preparing dataset ......
# [Dataset is ready now !]
# Ready to formatting on *bbox* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 86.3 task/s, elapsed: 3s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a5/bbox_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 312/312, 3150.9 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [312])file saved done in ../detection/cm_rcnn_10164_a5/bbox_dets.pkl
# Ready to evaluate on *bbox* ...
#
# TP: (2, 312)
# FP: (2, 312)
# FPR: (2, 312)
# TPR: (2, 312)
# AREA: [0.98604125 0.88389313] (2,)
# AP [0.9813587  0.88194017] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a5/voc_bbox_0.5_0.75.pkl]
# (2, 314) <class 'numpy.ndarray'>
# (2, 314) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 314) <class 'numpy.ndarray'>
# (2, 314) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a5/bbox_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a5/bbox_roc.png]
# Ready to formatting on *segm* ...
# [Building voc style GTS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 87.6 task/s, elapsed: 3s, ETA:     0s
# voc groundtruth file building done!
# Gt(gt numbers: [289])file saved done in ../detection/cm_rcnn_10164_a5/segm_gts.pkl
#
# [Building voc style DETS file......]
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 312/312, 1417.4 task/s, elapsed: 0s, ETA:     0s
# voc detection file building done!
# Det(det numbers: [312])file saved done in ../detection/cm_rcnn_10164_a5/segm_dets.pkl
# Ready to evaluate on *segm* ...
#
# TP: (2, 312)
# FP: (2, 312)
# FPR: (2, 312)
# TPR: (2, 312)
# AREA: [0.8170194  0.61828642] (2,)
# AP [0.89518118 0.32216281] (2,)
# voc formatted file save done![../detection/cm_rcnn_10164_a5/voc_segm_0.5_0.75.pkl]
# (2, 314) <class 'numpy.ndarray'>
# (2, 314) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
# (2, 314) <class 'numpy.ndarray'>
# (2, 314) <class 'numpy.ndarray'>
# (2,) <class 'numpy.ndarray'>
#
# Multiple pr lines
# Save done![../detection/cm_rcnn_10164_a5/segm_pr.png]
# Multiple roc lines
# Save done![../detection/cm_rcnn_10164_a5/segm_roc.png]

# %%
integration.integrated_loss_curve(name, save=True)
# Out:
#  Save done![../detection/cm_rcnn_10164_a5/learning_curve.png]
#  Save done![../detection/cm_rcnn_10164_a5/learing_rate.png]
